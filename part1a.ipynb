# %% [markdown]
# # EDA Assignment #1

# %% [markdown]
# ## Part 1A

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplt as plt
import seaborn as sns
import os
cd = os.getcwd()
print(cd)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-164-bf79dc207e63> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import matplotlib.pyplt as plt
#       5 import seaborn as sns
#       6 import os
#
# ModuleNotFoundError: No module named 'matplotlib.pyplt'

# %% [markdown]
# ### Read GSDP Data in a pandas dataframe

# %%
df_gsdp = pd.read_csv("gsdp_data.csv")
df_gsdp.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana      ...        Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.0      ...         359433.0  19208.0       724049.0     115523.0
# 1  347032.0      ...         401493.0  21663.0       822903.0     131835.0
# 2  400662.0      ...         452186.0  25593.0       944146.0     149817.0
# 3  437462.0      ...         511178.0  29667.0      1043371.0     161985.0
# 4  485184.0      ...         575631.0      NaN      1153795.0     184091.0
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  \
# 0           NaN                     3979.0     18768.0  343767.0     16818.0
# 1           NaN                     4421.0     21609.0  391238.0     18875.0
# 2           NaN                     5159.0     24787.0  443783.0     21870.0
# 3           NaN                     5721.0     27844.0  492424.0     24089.0
# 4           NaN                        NaN     30304.0  551963.0     26533.0
#
#    All_India GDP
# 0      8736039.0
# 1      9946636.0
# 2     11236635.0
# 3     12433749.0
# 4     13675331.0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Drop the columns for 2016-17 data

# %% [markdown]
# #### Remove the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (` in Crore)' for the year 2016-17.

# %%
#Copy in a new dataframe

df = df_gsdp.drop(index = df_gsdp[df_gsdp['Duration'] == '2016-17'].index, axis=0, inplace=False, errors = 'ignore')
df = df.drop(index = df[df['Duration'] == '2012-13'].index, axis=0, inplace=False, errors = 'ignore')
df = df.drop(index = df[df['Duration'] == '2011-12'].index, axis=0, inplace=False, errors = 'ignore')


#Remove West bengal also as does not have any data
#df = df.drop("West Bengal1",axis = 1, inplace=True)

df = df.T

#Make a common header combining values of "Items Description" and "Duration"
df.columns = df.iloc[0] +" for " + df.iloc[1]

#reset index as first columns is index column
df = df.reset_index(inplace=False)

df.rename(columns={"index":"state"},inplace=True)
#Drop "Item Description" & "Duration Row" 

# TBD why below lines to access these rows by name is not working
#df = df.drop("Items Description",axis=0,inplace=False)
#df = df.drop("Duration", axis=0, inplace = False)

df = df.drop([0], axis=0, inplace = False)
df = df.drop([1], axis=0, inplace = False)

df.head(40)
# Out:
#                         state GSDP - CURRENT PRICES (` in Crore) for 2013-14  \
# 2             Andhra Pradesh                                          464272
# 3           Arunachal Pradesh                                          14602
# 4                       Assam                                         177745
# 5                       Bihar                                         317101
# 6                Chhattisgarh                                         206690
# 7                         Goa                                          35921
# 8                     Gujarat                                         807623
# 9                     Haryana                                         400662
# 10           Himachal Pradesh                                          94764
# 11            Jammu & Kashmir                                          95893
# 12                  Jharkhand                                         188567
# 13                  Karnataka                                         817886
# 14                     Kerala                                         465041
# 15             Madhya Pradesh                                         437737
# 16                Maharashtra                                    1.64751e+06
# 17                    Manipur                                          16198
# 18                  Meghalaya                                          22938
# 19                    Mizoram                                          10293
# 20                   Nagaland                                          16612
# 21                     Odisha                                         291709
# 22                     Punjab                                         334714
# 23                  Rajasthan                                         549701
# 24                     Sikkim                                          13862
# 25                 Tamil Nadu                                         971090
# 26                  Telangana                                         452186
# 27                    Tripura                                          25593
# 28              Uttar Pradesh                                         944146
# 29                Uttarakhand                                         149817
# 30               West Bengal1                                            NaN
# 31  Andaman & Nicobar Islands                                           5159
# 32                 Chandigarh                                          24787
# 33                      Delhi                                         443783
# 34                 Puducherry                                          21870
# 35              All_India GDP                                    1.12366e+07
#
#    GSDP - CURRENT PRICES (` in Crore) for 2014-15  \
# 2                                          526468
# 3                                           16761
# 4                                          198098
# 5                                          373920
# 6                                          234982
# 7                                           40633
# 8                                          895027
# 9                                          437462
# 10                                         104369
# 11                                         100404
# 12                                         217107
# 13                                         921788
# 14                                         526002
# 15                                         481982
# 16                                    1.79212e+06
# 17                                          18043
# 18                                          24408
# 19                                          11559
# 20                                          18414
# 21                                         321971
# 22                                         368011
# 23                                         612194
# 24                                          15209
# 25                                    1.09256e+06
# 26                                         511178
# 27                                          29667
# 28                                    1.04337e+06
# 29                                         161985
# 30                                            NaN
# 31                                           5721
# 32                                          27844
# 33                                         492424
# 34                                          24089
# 35                                    1.24337e+07
#
#    GSDP - CURRENT PRICES (` in Crore) for 2015-16  \
# 2                                          609934
# 3                                           18784
# 4                                          224234
# 5                                          413503
# 6                                          260776
# 7                                           45002
# 8                                          994316
# 9                                          485184
# 10                                            NaN
# 11                                         118387
# 12                                         241955
# 13                                    1.02707e+06
# 14                                         588337
# 15                                         543975
# 16                                            NaN
# 17                                            NaN
# 18                                          26745
# 19                                            NaN
# 20                                            NaN
# 21                                         341887
# 22                                            NaN
# 23                                            NaN
# 24                                          16637
# 25                                    1.21267e+06
# 26                                         575631
# 27                                            NaN
# 28                                     1.1538e+06
# 29                                         184091
# 30                                            NaN
# 31                                            NaN
# 32                                          30304
# 33                                         551963
# 34                                          26533
# 35                                    1.36753e+07
#
#    (% Growth over previous year) for 2013-14  \
# 2                                      12.85
# 3                                      16.38
# 4                                      13.31
# 5                                       12.3
# 6                                      16.44
# 7                                      -5.77
# 8                                      11.47
# 9                                      15.45
# 10                                     14.42
# 11                                     10.09
# 12                                      7.92
# 13                                     18.24
# 14                                     12.79
# 15                                     14.91
# 16                                     13.74
# 17                                     17.83
# 18                                      4.87
# 19                                      23.1
# 20                                     21.98
# 21                                     12.95
# 22                                     12.42
# 23                                     11.27
# 24                                     12.35
# 25                                     13.51
# 26                                     12.63
# 27                                     18.14
# 28                                     14.73
# 29                                     13.64
# 30                                       NaN
# 31                                     16.68
# 32                                     14.71
# 33                                     13.43
# 34                                     15.87
# 35                                     12.97
#
#    (% Growth over previous year) for 2014-15  \
# 2                                       13.4
# 3                                      14.79
# 4                                      11.45
# 5                                      17.92
# 6                                      13.69
# 7                                      13.12
# 8                                      10.82
# 9                                       9.18
# 10                                     10.14
# 11                                       4.7
# 12                                     15.14
# 13                                      12.7
# 14                                     13.11
# 15                                     10.11
# 16                                      8.78
# 17                                     11.39
# 18                                      6.41
# 19                                      12.3
# 20                                     10.85
# 21                                     10.37
# 22                                      9.95
# 23                                     11.37
# 24                                      9.72
# 25                                     12.51
# 26                                     13.05
# 27                                     15.92
# 28                                     10.51
# 29                                      8.12
# 30                                       NaN
# 31                                     10.89
# 32                                     12.33
# 33                                     10.96
# 34                                     10.14
# 35                                     10.65
#
#    (% Growth over previous year) for 2015-16
# 2                                      15.85
# 3                                      12.07
# 4                                      13.19
# 5                                      10.59
# 6                                      10.98
# 7                                      10.75
# 8                                      11.09
# 9                                      10.91
# 10                                       NaN
# 11                                     17.91
# 12                                     11.44
# 13                                     11.42
# 14                                     11.85
# 15                                     12.86
# 16                                       NaN
# 17                                       NaN
# 18                                      9.58
# 19                                       NaN
# 20                                       NaN
# 21                                      6.19
# 22                                       NaN
# 23                                       NaN
# 24                                      9.39
# 25                                     10.99
# 26                                     12.61
# 27                                       NaN
# 28                                     10.58
# 29                                     13.65
# 30                                       NaN
# 31                                       NaN
# 32                                      8.84
# 33                                     12.09
# 34                                     10.15
# 35                                      9.99

# %% [markdown]
# ##### Calculate the average growth of states over the duration 2013-14, 2014-15 and 2015-16 by taking the mean of the row '(% Growth over previous year)'. Compare the calculated value and plot it for the states.

# %%
# TBD Ideally we should have made a pivot for (% Growth over previous year) and then filter for 2013-14, 2014-15 and 2015-16

#In absence, calculate average directly and add as a new column

df["average growth"] = np.mean([df["(% Growth over previous year) for 2013-14"], 
                               df["(% Growth over previous year) for 2014-15"],
                               df["(% Growth over previous year) for 2015-16"]], 
                               axis = 0)

#drop the values with average growth
df = df.dropna(subset=["average growth"])

df.sort_values(by="average growth", axis=0, ascending=False, inplace = True )

df.head(30)
# Out:
#                 state GSDP - CURRENT PRICES (` in Crore) for 2013-14  \
# 3   Arunachal Pradesh                                          14602
# 13          Karnataka                                         817886
# 2     Andhra Pradesh                                          464272
# 6        Chhattisgarh                                         206690
# 5               Bihar                                         317101
# 26          Telangana                                         452186
# 4               Assam                                         177745
# 15     Madhya Pradesh                                         437737
# 14             Kerala                                         465041
# 25         Tamil Nadu                                         971090
# 33              Delhi                                         443783
# 34         Puducherry                                          21870
# 32         Chandigarh                                          24787
# 28      Uttar Pradesh                                         944146
# 9             Haryana                                         400662
# 29        Uttarakhand                                         149817
# 12          Jharkhand                                         188567
# 35      All_India GDP                                    1.12366e+07
# 8             Gujarat                                         807623
# 11    Jammu & Kashmir                                          95893
# 24             Sikkim                                          13862
# 21             Odisha                                         291709
# 18          Meghalaya                                          22938
# 7                 Goa                                          35921
#
#    GSDP - CURRENT PRICES (` in Crore) for 2014-15  \
# 3                                           16761
# 13                                         921788
# 2                                          526468
# 6                                          234982
# 5                                          373920
# 26                                         511178
# 4                                          198098
# 15                                         481982
# 14                                         526002
# 25                                    1.09256e+06
# 33                                         492424
# 34                                          24089
# 32                                          27844
# 28                                    1.04337e+06
# 9                                          437462
# 29                                         161985
# 12                                         217107
# 35                                    1.24337e+07
# 8                                          895027
# 11                                         100404
# 24                                          15209
# 21                                         321971
# 18                                          24408
# 7                                           40633
#
#    GSDP - CURRENT PRICES (` in Crore) for 2015-16  \
# 3                                           18784
# 13                                    1.02707e+06
# 2                                          609934
# 6                                          260776
# 5                                          413503
# 26                                         575631
# 4                                          224234
# 15                                         543975
# 14                                         588337
# 25                                    1.21267e+06
# 33                                         551963
# 34                                          26533
# 32                                          30304
# 28                                     1.1538e+06
# 9                                          485184
# 29                                         184091
# 12                                         241955
# 35                                    1.36753e+07
# 8                                          994316
# 11                                         118387
# 24                                          16637
# 21                                         341887
# 18                                          26745
# 7                                           45002
#
#    (% Growth over previous year) for 2013-14  \
# 3                                      16.38
# 13                                     18.24
# 2                                      12.85
# 6                                      16.44
# 5                                       12.3
# 26                                     12.63
# 4                                      13.31
# 15                                     14.91
# 14                                     12.79
# 25                                     13.51
# 33                                     13.43
# 34                                     15.87
# 32                                     14.71
# 28                                     14.73
# 9                                      15.45
# 29                                     13.64
# 12                                      7.92
# 35                                     12.97
# 8                                      11.47
# 11                                     10.09
# 24                                     12.35
# 21                                     12.95
# 18                                      4.87
# 7                                      -5.77
#
#    (% Growth over previous year) for 2014-15  \
# 3                                      14.79
# 13                                      12.7
# 2                                       13.4
# 6                                      13.69
# 5                                      17.92
# 26                                     13.05
# 4                                      11.45
# 15                                     10.11
# 14                                     13.11
# 25                                     12.51
# 33                                     10.96
# 34                                     10.14
# 32                                     12.33
# 28                                     10.51
# 9                                       9.18
# 29                                      8.12
# 12                                     15.14
# 35                                     10.65
# 8                                      10.82
# 11                                       4.7
# 24                                      9.72
# 21                                     10.37
# 18                                      6.41
# 7                                      13.12
#
#    (% Growth over previous year) for 2015-16 average growth
# 3                                      12.07        14.4133
# 13                                     11.42          14.12
# 2                                      15.85        14.0333
# 6                                      10.98        13.7033
# 5                                      10.59        13.6033
# 26                                     12.61        12.7633
# 4                                      13.19          12.65
# 15                                     12.86        12.6267
# 14                                     11.85        12.5833
# 25                                     10.99        12.3367
# 33                                     12.09          12.16
# 34                                     10.15        12.0533
# 32                                      8.84          11.96
# 28                                     10.58          11.94
# 9                                      10.91        11.8467
# 29                                     13.65        11.8033
# 12                                     11.44           11.5
# 35                                      9.99        11.2033
# 8                                      11.09        11.1267
# 11                                     17.91           10.9
# 24                                      9.39        10.4867
# 21                                      6.19        9.83667
# 18                                      9.58        6.95333
# 7                                      10.75        6.03333

# %%
#Plot average growth
import matplotlib.pyplot as plt
import seaborn as sns

all_india_gdp = df[df['state'] == "All_India GDP"]['average growth']

print(all_india_gdp)

df = df.drop(df[df['state'] == "All_India GDP"].index,axis=0,inplace=False)

plt.figure(figsize =(12,10))
sns.barplot(x="average growth",y="state",data=df)
plt.show()
# Out:
# Series([], Name: average growth, dtype: object)

# %%
#Plot the total GDP of the states for the year 2015-16:
df_gdp = df.sort_values("GSDP - CURRENT PRICES (` in Crore) for 2015-16",ascending=False)

plt.figure(figsize = (12,10))
sns.barplot("GSDP - CURRENT PRICES (` in Crore) for 2015-16","state",data=df_gdp)

plt.show()

# %% [markdown]
# ## Part 1B EDA Exercise

# %% [markdown]
# ### 1st exercise to plot GDP Per capita for states in descending order

# %%
#Read All CSVs and append the names in a list

states = []
df = pd.DataFrame([])
df_temp = []
states_gdp = []

states_gdp = pd.read_csv("NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv")
states_gdp.drop(["S.No.","2011-12","2012-13","2013-14","2014-15","2015-16","2016-17"],axis=1,inplace=True)
states_gdp.reset_index()


for root, dir, files in os.walk('.'):
    for file in files:
        if(file.endswith('.csv') and file.startswith('NAD') ):
            #print(file)
            file_name_split = file.split("-")
            state = file_name_split[1]
            states.append(state)
            if(state != "Manipur"):
                df_temp = pd.read_csv(file)
            else:
                df_temp = pd.read_csv(file, encoding='latin-1')
                
            df_temp.rename(columns={"2014-15":state},inplace=True)
            states_gdp = pd.concat([states_gdp,df_temp[state]], axis=1)

#drop union territories column
union_territores = ["Delhi","Puducherry"]
states_gdp = states_gdp.drop(union_territores,axis=1,inplace=False, errors='ignore')

states_gdp.head()
# Out:
#                                 Item  Andhra_Pradesh  Arunachal_Pradesh  \
# 0  Agriculture, forestry and fishing        14819416             686117
# 1                              Crops         7893514             415520
# 2                          Livestock         4309078              38387
# 3               Forestry and logging          346160             224017
# 4            Fishing and aquaculture         2270664               8193
#
#      Assam    Bihar  Chandigarh  Chhattisgarh     Goa     Gujarat    Haryana  \
# 0  3855548  7951890       16233       3948847  308507  13769969.0  8015238.0
# 1  2890544  4688237        1659       2613371  140421   9671086.0  4636731.0
# 2   173478  2060296       13992        352208   30141   2698910.0  2916173.0
# 3   261987   550132         388        597785   15744    761616.0   352254.0
# 4   529539   653224         194        385483  122201    638357.0   110080.0
#
#         ...         Odisha   Punjab  Rajasthan  Sikkim  Tamil_Nadu  Telangana  \
# 0       ...        6422978  9285716   15044394  137447    13064238    7591501
# 1       ...        4382636  5690972    7673441  114976     7297820    4162493
# 2       ...         788243  2638842    5356257   17338     4693361    2951299
# 3       ...         791463   848245    1956660    4529      392705     210741
# 4       ...         460636   107657      58036     604      680352     266968
#
#     Tripura  Uttarakhand  Uttar_Pradesh  Andhra_Pradesh
# 0  799825.0    1601423.0       25097754        14819416
# 1  397591.0     866146.0       16215212         7893514
# 2   88176.0     391188.0        7096876         4309078
# 3  145096.0     339293.0        1404936          346160
# 4  168961.0       4796.0         380730         2270664
#
# [5 rows x 31 columns]

# %%
#Set Header as Item
states_gdp = states_gdp.T
states_gdp.columns = states_gdp.iloc[0]
states_gdp = states_gdp.drop(states_gdp.index[0])

#states_gdp.reset_index(inplace=True)
#states_gdp.rename(columns={"index":"State"}, inplace=True)

states_gdp.sort_values("Per Capita GSDP (Rs.)", axis = 0, ascending = False, 
                 inplace = True, na_position ='last') 


states_gdp.head()
# Out:
# Item       Agriculture, forestry and fishing        Crops    Livestock  \
# Goa                                   308507       140421        30141
# Chandigarh                             16233         1659        13992
# Sikkim                                137447       114976        17338
# Haryana                          8.01524e+06  4.63673e+06  2.91617e+06
# Kerala                               5930617      3070386      1656104
#
# Item       Forestry and logging Fishing and aquaculture Mining and quarrying  \
# Goa                       15744                  122201                 3622
# Chandigarh                  388                     194                  179
# Sikkim                     4529                     604                 1329
# Haryana                  352254                  110080                25186
# Kerala                   499808                  704319               558824
#
# Item            Primary Manufacturing  \
# Goa              312129       1177608
# Chandigarh        16412        149631
# Sikkim           138776        550697
# Haryana     8.04042e+06   7.75692e+06
# Kerala          6489442       4273567
#
# Item       Electricity, gas, water supply & other utility services  \
# Goa                                                    204110
# Chandigarh                                              29741
# Sikkim                                                 212499
# Haryana                                           1.10192e+06
# Kerala                                                 482470
#
# Item       Construction          ...           \
# Goa              165819          ...
# Chandigarh       133321          ...
# Sikkim            82058          ...
# Haryana     3.70257e+06          ...
# Kerala          7314003          ...
#
# Item       Real estate, ownership of dwelling & professional services  \
# Goa                                                    407099
# Chandigarh                                             598448
# Sikkim                                                  75330
# Haryana                                           6.97018e+06
# Kerala                                                7287633
#
# Item       Public administration Other services     Tertiary  \
# Goa                       346486         180431      1738217
# Chandigarh                183889         156543      2426008
# Sikkim                    119514         149265       483103
# Haryana              1.03638e+06    2.00158e+06  1.92266e+07
# Kerala                   2068915        5728645     29673778
#
# Item       TOTAL GSVA at basic prices Taxes on Products Subsidies on products  \
# Goa                           3597882            527279                 61854
# Chandigarh                    2755113             52622                 23309
# Sikkim                        1467133             72200                 18400
# Haryana                   3.98284e+07       4.98567e+06           1.06787e+06
# Kerala                       48233259           5189352                822381
#
# Item       Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)
# Goa                             4063307            14950                271793
# Chandigarh                      2784426            11120                250398
# Sikkim                          1520933             6330                240274
# Haryana                     4.37462e+07           266620                164077
# Kerala                         52600230           339843                154778
#
# [5 rows x 33 columns]

# %%
#Plot the states GDP per capita
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize =(12,10))
#sns.barplot(x="Per Capita GSDP (Rs.)",y="State",data=states_gdp)
sns.barplot(x="Per Capita GSDP (Rs.)",y=states_gdp.index,data=states_gdp)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Plot the percentage contribution of primary, secondary and tertiary sectors as a percentage of total GDP for all the states

# %%
states_gdp["%Primary"] = (states_gdp["Primary"]*100)/(states_gdp["Primary"] + states_gdp["Secondary"] + states_gdp["Tertiary"])
states_gdp["%Secondary"] = (states_gdp["Secondary"]*100)/(states_gdp["Primary"] + states_gdp["Secondary"] + states_gdp["Tertiary"])
states_gdp["%Tertiary"] = (states_gdp["Tertiary"]*100)/(states_gdp["Primary"] + states_gdp["Secondary"] + states_gdp["Tertiary"])
states_gdp.head()
# Out:
# Item       Agriculture, forestry and fishing        Crops    Livestock  \
# Goa                                   308507       140421        30141
# Chandigarh                             16233         1659        13992
# Sikkim                                137447       114976        17338
# Haryana                          8.01524e+06  4.63673e+06  2.91617e+06
# Kerala                               5930617      3070386      1656104
#
# Item       Forestry and logging Fishing and aquaculture Mining and quarrying  \
# Goa                       15744                  122201                 3622
# Chandigarh                  388                     194                  179
# Sikkim                     4529                     604                 1329
# Haryana                  352254                  110080                25186
# Kerala                   499808                  704319               558824
#
# Item            Primary Manufacturing  \
# Goa              312129       1177608
# Chandigarh        16412        149631
# Sikkim           138776        550697
# Haryana     8.04042e+06   7.75692e+06
# Kerala          6489442       4273567
#
# Item       Electricity, gas, water supply & other utility services  \
# Goa                                                    204110
# Chandigarh                                              29741
# Sikkim                                                 212499
# Haryana                                           1.10192e+06
# Kerala                                                 482470
#
# Item       Construction    ...        Tertiary TOTAL GSVA at basic prices  \
# Goa              165819    ...         1738217                    3597882
# Chandigarh       133321    ...         2426008                    2755113
# Sikkim            82058    ...          483103                    1467133
# Haryana     3.70257e+06    ...     1.92266e+07                3.98284e+07
# Kerala          7314003    ...        29673778                   48233259
#
# Item       Taxes on Products Subsidies on products  \
# Goa                   527279                 61854
# Chandigarh             52622                 23309
# Sikkim                 72200                 18400
# Haryana          4.98567e+06           1.06787e+06
# Kerala               5189352                822381
#
# Item       Gross State Domestic Product Population ('00)  \
# Goa                             4063307            14950
# Chandigarh                      2784426            11120
# Sikkim                          1520933             6330
# Haryana                     4.37462e+07           266620
# Kerala                         52600230           339843
#
# Item       Per Capita GSDP (Rs.)  %Primary %Secondary %Tertiary
# Goa                       271793   8.67535    43.0124   48.3122
# Chandigarh                250398  0.595692    11.3496   88.0548
# Sikkim                    240274     9.459    57.6126   32.9284
# Haryana                   164077   20.1877    31.5388   48.2735
# Kerala                    154778   13.4543    25.0243   61.5214
#
# [5 rows x 36 columns]

# %%
#SHow the Trends using 3 different plots
plt.figure(figsize =(12,20))

plt.subplot(3,1,1)
plt.title('%Contribution of Primary to GDP')
sns.barplot(x="%Primary",y=states_gdp.index,data=states_gdp)
plt.show()

plt.figure(figsize =(12,20))

plt.subplot(3,1,2)
plt.title('%Contribution of Secondary to GDP')
sns.barplot(x="%Secondary",y=states_gdp.index,data=states_gdp)
plt.show()

plt.figure(figsize =(12,20))

plt.subplot(3,1,1)
plt.title('%Contribution of Tertiary to GDP')
sns.barplot(x="%Tertiary",y=states_gdp.index,data=states_gdp)
plt.show()

# %%
#Show using stacked barchart
states_gdp[["%Primary","%Secondary","%Tertiary"]].plot(kind='bar', stacked=True,figsize=(12,10),title="%sector contribution to GDP")
plt.show()

# %% [markdown]
# ### Part 3
#
# * Categorise the states into four categories based on GDP per capita (C1, C2, C3, C4 - C1 would have the highest per capita GDP, C4 the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e. the states lying between the 85th and the 100th percentile are in C1, those between 50th and 85th percentile are in C2 and so on

# %%
# Create a new column based for categories C1, C2, C3, C4 Calculated based on Quantile values of Per Capita GSDP
states_gdp['GDP Category'] = pd.qcut(states_gdp['Per Capita GSDP (Rs.)'], [0,0.20,0.5, 0.85, 1], labels=['C4','C3','C2','C1'])

states_gdp
# Out:
# Item              Agriculture, forestry and fishing        Crops    Livestock  \
# Goa                                          308507       140421        30141
# Chandigarh                                    16233         1659        13992
# Sikkim                                       137447       114976        17338
# Haryana                                 8.01524e+06  4.63673e+06  2.91617e+06
# Kerala                                      5930617      3070386      1656104
# Uttarakhand                             1.60142e+06       866146       391188
# Maharashtra                                16475655     10435121      3972829
# Himachal_Pradesh                            1514981       853758       110304
# Tamil_Nadu                                 13064238      7297820      4693361
# Karnataka                                  11219422      8157179      1868771
# Gujarat                                   1.377e+07  9.67109e+06  2.69891e+06
# Telangana                                   7591501      4162493      2951299
# Punjab                                      9285716      5690972      2638842
# Arunachal_Pradesh                            686117       415520        38387
# Andhra_Pradesh                             14819416      7893514      4309078
# Andhra_Pradesh                             14819416      7893514      4309078
# Mizoram                                      217010       116609        45590
# Nagaland                                     607897       375825       123800
# Chhattisgarh                                3948847      2613371       352208
# Rajasthan                                  15044394      7673441      5356257
# Tripura                                      799825       397591        88176
# Meghalaya                                    366521       223330        72442
# Jammu_Kashmir                               1586705       949424       433133
# Odisha                                      6422978      4382636       788243
# Madhya_Pradesh                             16235647     13216013      1932769
# Jharkhand                                   3211065      2094466       562503
# Assam                                       3855548      2890544       173478
# Manipur                                      383140       226583        75483
# Uttar_Pradesh                              25097754     16215212      7096876
# Bihar                                       7951890      4688237      2060296
#
# Item              Forestry and logging Fishing and aquaculture  \
# Goa                              15744                  122201
# Chandigarh                         388                     194
# Sikkim                            4529                     604
# Haryana                         352254                  110080
# Kerala                          499808                  704319
# Uttarakhand                     339293                    4796
# Maharashtra                    1592564                  475141
# Himachal_Pradesh                540950                    9968
# Tamil_Nadu                      392705                  680352
# Karnataka                       693082                  500390
# Gujarat                         761616                  638357
# Telangana                       210741                  266968
# Punjab                          848245                  107657
# Arunachal_Pradesh               224017                    8193
# Andhra_Pradesh                  346160                 2270664
# Andhra_Pradesh                  346160                 2270664
# Mizoram                          47763                    7048
# Nagaland                         99802                    8470
# Chhattisgarh                    597785                  385483
# Rajasthan                      1956660                   58036
# Tripura                         145096                  168961
# Meghalaya                        61166                    9583
# Jammu_Kashmir                   168093                   36055
# Odisha                          791463                  460636
# Madhya_Pradesh                  965588                  121277
# Jharkhand                       445149                  108947
# Assam                           261987                  529539
# Manipur                          45831                   35243
# Uttar_Pradesh                  1404936                  380730
# Bihar                           550132                  653224
#
# Item              Mining and quarrying      Primary Manufacturing  \
# Goa                               3622       312129       1177608
# Chandigarh                         179        16412        149631
# Sikkim                            1329       138776        550697
# Haryana                          25186  8.04042e+06   7.75692e+06
# Kerala                          558824      6489442       4273567
# Uttarakhand                     244549  1.84597e+06   5.86625e+06
# Maharashtra                    5282727     21758383      33660294
# Himachal_Pradesh                 33385      1548366       2543637
# Tamil_Nadu                      265536     13329774      18914794
# Karnataka                       846882     12066304      12953843
# Gujarat                    2.11722e+06  1.58872e+07   2.40875e+07
# Telangana                      1541853      9133354       6353711
# Punjab                           10354      9296070       4790341
# Arunachal_Pradesh                30842       716959         26120
# Andhra_Pradesh                 1484300     16303716       4672266
# Andhra_Pradesh                 1484300     16303716       4672266
# Mizoram                           8588       225598          8479
# Nagaland                          8280       616178         18346
# Chhattisgarh                   2451970      6400817       4370593
# Rajasthan                      4069385     19113780       6552580
# Tripura                         142391       942216        228625
# Meghalaya                        84529       451050        433213
# Jammu_Kashmir                    33621      1620326        893207
# Odisha                         2586328      9009306       5754229
# Madhya_Pradesh                 1618373     17854020       4368833
# Jharkhand                      2037289      5248354       4114148
# Assam                          1471149      5326697       2002936
# Manipur                            NaN       383140         49501
# Uttar_Pradesh                   901501     25999255      12261649
# Bihar                            68107      8019997       2189965
#
# Item              Electricity, gas, water supply & other utility services  \
# Goa                                                           204110
# Chandigarh                                                     29741
# Sikkim                                                        212499
# Haryana                                                  1.10192e+06
# Kerala                                                        482470
# Uttarakhand                                                   433880
# Maharashtra                                                  4334702
# Himachal_Pradesh                                              767268
# Tamil_Nadu                                                   1710379
# Karnataka                                                    1425762
# Gujarat                                                  3.40998e+06
# Telangana                                                     716266
# Punjab                                                        911611
# Arunachal_Pradesh                                             113527
# Andhra_Pradesh                                               1151729
# Andhra_Pradesh                                               1151729
# Mizoram                                                       128365
# Nagaland                                                       37944
# Chhattisgarh                                                 1198438
# Rajasthan                                                    1122888
# Tripura                                                        77870
# Meghalaya                                                      54473
# Jammu_Kashmir                                                 597421
# Odisha                                                        833067
# Madhya_Pradesh                                               1272905
# Jharkhand                                                     337489
# Assam                                                         296587
# Manipur                                                        27490
# Uttar_Pradesh                                                2030625
# Bihar                                                         345168
#
# Item              Construction     ...      TOTAL GSVA at basic prices  \
# Goa                     165819     ...                         3597882
# Chandigarh              133321     ...                         2755113
# Sikkim                   82058     ...                         1467133
# Haryana            3.70257e+06     ...                     3.98284e+07
# Kerala                 7314003     ...                        48233259
# Uttarakhand        1.34273e+06     ...                     1.50768e+07
# Maharashtra            9450211     ...                       157834665
# Himachal_Pradesh        808256     ...                         9800853
# Tamil_Nadu            12216718     ...                        99515453
# Karnataka              6104799     ...                        83041338
# Gujarat            5.52602e+06     ...                     7.91311e+07
# Telangana              2854024     ...                        47528765
# Punjab                 2202962     ...                        33918789
# Arunachal_Pradesh       147842     ...                         1636292
# Andhra_Pradesh         4664889     ...                        48825542
# Andhra_Pradesh         4664889     ...                        48825542
# Mizoram                 133228     ...                         1133289
# Nagaland                156072     ...                         1821495
# Chhattisgarh           2669855     ...                        22228481
# Rajasthan              5353326     ...                        58158386
# Tripura                 177899     ...                     2.91132e+06
# Meghalaya               150256     ...                     2.28965e+06
# Jammu_Kashmir           785503     ...                         9509739
# Odisha                 2402396     ...                        30255256
# Madhya_Pradesh         4403151     ...                        46016269
# Jharkhand              1789834     ...                        19623166
# Assam                  1733568     ...                        18666897
# Manipur                 143182     ...                     1.78065e+06
# Uttar_Pradesh         11256450     ...                        97516938
# Bihar                  3449763     ...                        36184863
#
# Item              Taxes on Products Subsidies on products  \
# Goa                          527279                 61854
# Chandigarh                    52622                 23309
# Sikkim                        72200                 18400
# Haryana                 4.98567e+06           1.06787e+06
# Kerala                      5189352                822381
# Uttarakhand             1.43486e+06                313139
# Maharashtra                25394800               4017300
# Himachal_Pradesh             895317                259291
# Tamil_Nadu                 12507325               2766405
# Karnataka                  11026674               1889206
# Gujarat                 1.23532e+07           1.98155e+06
# Telangana                   4425700                836700
# Punjab                      3794100                911800
# Arunachal_Pradesh             70099                 30272
# Andhra_Pradesh              5512100               1690800
# Andhra_Pradesh              5512100               1690800
# Mizoram                       43084                 20440
# Nagaland                      57674                 37745
# Chhattisgarh                2601791               1332092
# Rajasthan                   5394503               2333442
# Tripura                      149345                 94002
# Meghalaya                    213272                 62112
# Jammu_Kashmir                764270                233563
# Odisha                      3151184               1209349
# Madhya_Pradesh              4284700               2102800
# Jharkhand                   2499171                411619
# Assam                       1725309                582406
# Manipur                       92766                 69137
# Uttar_Pradesh              10107396               3287219
# Bihar                       3213546               2006421
#
# Item              Gross State Domestic Product Population ('00)  \
# Goa                                    4063307            14950
# Chandigarh                             2784426            11120
# Sikkim                                 1520933             6330
# Haryana                            4.37462e+07           266620
# Kerala                                52600230           339843
# Uttarakhand                        1.61985e+07           105820
# Maharashtra                          179212165          1172450
# Himachal_Pradesh                      10436879            70840
# Tamil_Nadu                           109256373           745760
# Karnataka                             92178806           635100
# Gujarat                            8.95027e+07           633590
# Telangana                             51117765           367660
# Punjab                                36801089           290673
# Arunachal_Pradesh                      1676119            14870
# Andhra_Pradesh                        52646842           501510
# Andhra_Pradesh                        52646842           501510
# Mizoram                                1155933            11833
# Nagaland                               1841424            20550
# Chhattisgarh                          23498180           270530
# Rajasthan                             61219447           721610
# Tripura                            2.96666e+06            38350
# Meghalaya                          2.44081e+06            32020
# Jammu_Kashmir                         10040446           132390
# Odisha                                32197092           435220
# Madhya_Pradesh                        48198169           765180
# Jharkhand                             21710718           349660
# Assam                                 19809800           326780
# Manipur                            1.80428e+06            30873
# Uttar_Pradesh                        104337115          2109940
# Bihar                                 37391988          1101240
#
# Item              Per Capita GSDP (Rs.)  %Primary %Secondary %Tertiary  \
# Goa                              271793   8.67535    43.0124   48.3122
# Chandigarh                       250398  0.595692    11.3496   88.0548
# Sikkim                           240274     9.459    57.6126   32.9284
# Haryana                          164077   20.1877    31.5388   48.2735
# Kerala                           154778   13.4543    25.0243   61.5214
# Uttarakhand                      153076   12.2438    50.6928   37.0634
# Maharashtra                      152853   13.7856    30.0601   56.1544
# Himachal_Pradesh                 147330   15.7983    42.0286   42.1731
# Tamil_Nadu                       146503   13.3947    33.0018   53.6035
# Karnataka                        145141   14.5305    24.6677   60.8018
# Gujarat                          141263    20.077    41.7327   38.1903
# Telangana                        139035   19.2165      20.88   59.9035
# Punjab                           126606   27.4068    23.3054   49.2877
# Arunachal_Pradesh                112718   43.8161    17.5695   38.6144
# Andhra_Pradesh                   104977   33.3918    21.4824   45.1259
# Andhra_Pradesh                   104977   33.3918    21.4824   45.1259
# Mizoram                           97687   19.9065    23.8308   56.2627
# Nagaland                          89607   33.8281    11.6586   54.5132
# Chhattisgarh                      86860   28.7956    37.0645   34.1399
# Rajasthan                         84837    32.865    22.4023   44.7327
# Tripura                           77358   32.3639    16.6383   50.9978
# Meghalaya                         76228   19.6995     27.862   52.4384
# Jammu_Kashmir                     75840   17.0386    23.9347   59.0267
# Odisha                            73979   29.7777    29.7128   40.5095
# Madhya_Pradesh                    62989   38.7994     21.829   39.3716
# Jharkhand                         62091   26.7457    31.8066   41.4476
# Assam                             60621   28.5355    21.6056   49.8589
# Manipur                           58442   21.5169    12.3648   66.1183
# Uttar_Pradesh                     49450   26.6613    26.1993   47.1395
# Bihar                             33954    22.164    16.5398   61.2963
#
# Item              GDP Category
# Goa                         C1
# Chandigarh                  C1
# Sikkim                      C1
# Haryana                     C1
# Kerala                      C1
# Uttarakhand                 C2
# Maharashtra                 C2
# Himachal_Pradesh            C2
# Tamil_Nadu                  C2
# Karnataka                   C2
# Gujarat                     C2
# Telangana                   C2
# Punjab                      C2
# Arunachal_Pradesh           C2
# Andhra_Pradesh              C3
# Andhra_Pradesh              C3
# Mizoram                     C3
# Nagaland                    C3
# Chhattisgarh                C3
# Rajasthan                   C3
# Tripura                     C3
# Meghalaya                   C3
# Jammu_Kashmir               C3
# Odisha                      C3
# Madhya_Pradesh              C4
# Jharkhand                   C4
# Assam                       C4
# Manipur                     C4
# Uttar_Pradesh               C4
# Bihar                       C4
#
# [30 rows x 37 columns]

# %% [markdown]
# #### Find the top 3/4/5 sub-sectors (such as agriculture, forestry and fishing, crops, manufacturing etc.) [not primary, secondary and tertiary] which contribute to approx. 80% of the GSDP of each category

# %%
#extract C1,C2,C3,C4 states in different dataframes
c1_states = states_gdp[states_gdp["GDP Category"] == "C1"]
c2_states = states_gdp[states_gdp["GDP Category"] == "C2"]
c3_states = states_gdp[states_gdp["GDP Category"] == "C3"]
c4_states = states_gdp[states_gdp["GDP Category"] == "C4"]

c1_states
# Out:
# Item       Agriculture, forestry and fishing        Crops    Livestock  \
# Goa                                   308507       140421        30141
# Chandigarh                             16233         1659        13992
# Sikkim                                137447       114976        17338
# Haryana                          8.01524e+06  4.63673e+06  2.91617e+06
# Kerala                               5930617      3070386      1656104
#
# Item       Forestry and logging Fishing and aquaculture Mining and quarrying  \
# Goa                       15744                  122201                 3622
# Chandigarh                  388                     194                  179
# Sikkim                     4529                     604                 1329
# Haryana                  352254                  110080                25186
# Kerala                   499808                  704319               558824
#
# Item            Primary Manufacturing  \
# Goa              312129       1177608
# Chandigarh        16412        149631
# Sikkim           138776        550697
# Haryana     8.04042e+06   7.75692e+06
# Kerala          6489442       4273567
#
# Item       Electricity, gas, water supply & other utility services  \
# Goa                                                    204110
# Chandigarh                                              29741
# Sikkim                                                 212499
# Haryana                                           1.10192e+06
# Kerala                                                 482470
#
# Item       Construction     ...      TOTAL GSVA at basic prices  \
# Goa              165819     ...                         3597882
# Chandigarh       133321     ...                         2755113
# Sikkim            82058     ...                         1467133
# Haryana     3.70257e+06     ...                     3.98284e+07
# Kerala          7314003     ...                        48233259
#
# Item       Taxes on Products Subsidies on products  \
# Goa                   527279                 61854
# Chandigarh             52622                 23309
# Sikkim                 72200                 18400
# Haryana          4.98567e+06           1.06787e+06
# Kerala               5189352                822381
#
# Item       Gross State Domestic Product Population ('00)  \
# Goa                             4063307            14950
# Chandigarh                      2784426            11120
# Sikkim                          1520933             6330
# Haryana                     4.37462e+07           266620
# Kerala                         52600230           339843
#
# Item       Per Capita GSDP (Rs.)  %Primary %Secondary %Tertiary GDP Category
# Goa                       271793   8.67535    43.0124   48.3122           C1
# Chandigarh                250398  0.595692    11.3496   88.0548           C1
# Sikkim                    240274     9.459    57.6126   32.9284           C1
# Haryana                   164077   20.1877    31.5388   48.2735           C1
# Kerala                    154778   13.4543    25.0243   61.5214           C1
#
# [5 rows x 37 columns]

# %%
# for each category,drop unnecessary columns and transpose
c1_states = c1_states.reset_index()
c2_states = c2_states.reset_index()
c3_states = c3_states.reset_index()
c4_states = c4_states.reset_index()


c1_states = c1_states.drop(["index","Primary","Secondary",'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products', 'Gross State Domestic Product',
       "Population ('00)", 'Per Capita GSDP (Rs.)', '%Primary', '%Secondary',
       '%Tertiary', 'GDP Category'],axis=1).T

c2_states = c2_states.drop(["index","Primary","Secondary",'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products', 'Gross State Domestic Product',
       "Population ('00)", 'Per Capita GSDP (Rs.)', '%Primary', '%Secondary',
       '%Tertiary', 'GDP Category'],axis=1).T

c3_states = c3_states.drop(["index","Primary","Secondary",'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products', 'Gross State Domestic Product',
       "Population ('00)", 'Per Capita GSDP (Rs.)', '%Primary', '%Secondary',
       '%Tertiary', 'GDP Category'],axis=1).T

c4_states = c4_states.drop(["index","Primary","Secondary",'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products', 'Gross State Domestic Product',
       "Population ('00)", 'Per Capita GSDP (Rs.)', '%Primary', '%Secondary',
       '%Tertiary', 'GDP Category'],axis=1).T

c4_states
# Out:
#                                                            0        1  \
# Item
# Agriculture, forestry and fishing                   16235647  3211065
# Crops                                               13216013  2094466
# Livestock                                            1932769   562503
# Forestry and logging                                  965588   445149
# Fishing and aquaculture                               121277   108947
# Mining and quarrying                                 1618373  2037289
# Manufacturing                                        4368833  4114148
# Electricity, gas, water supply & other utility ...   1272905   337489
# Construction                                         4403151  1789834
# Trade, repair, hotels and restaurants                5357515  1991359
# Trade & repair services                              5053625  1840196
# Hotels & restaurants                                  303890   151163
# Transport, storage, communication & services re...   2865802  1470022
# Railways                                              498734   472702
# Road transport                                       1369235   649648
# Water transport                                            0        0
# Air transport                                          26746     6716
# Services incidental to transport                       36694    17436
# Storage                                                29012      306
# Communication & services related to broadcasting      905381   323214
# Financial services                                   1988794   551441
# Real estate, ownership of dwelling & profession...   2660123  1656784
# Public administration                                2497321  1088325
# Other services                                       2747805  1375410
#
#                                                           2       3         4  \
# Item
# Agriculture, forestry and fishing                   3855548  383140  25097754
# Crops                                               2890544  226583  16215212
# Livestock                                            173478   75483   7096876
# Forestry and logging                                 261987   45831   1404936
# Fishing and aquaculture                              529539   35243    380730
# Mining and quarrying                                1471149     NaN    901501
# Manufacturing                                       2002936   49501  12261649
# Electricity, gas, water supply & other utility ...   296587   27490   2030625
# Construction                                        1733568  143182  11256450
# Trade, repair, hotels and restaurants               2987155  262950   9437243
# Trade & repair services                             2876251  253637   8476139
# Hotels & restaurants                                 110904    9313    961104
# Transport, storage, communication & services re...  1194568  109726   7404509
# Railways                                             252509       6   1618742
# Road transport                                       507668   58974   3645747
# Water transport                                        4502     NaN       681
# Air transport                                         26223    6288     36582
# Services incidental to transport                      35739    2441     16323
# Storage                                               10308     NaN    171696
# Communication & services related to broadcasting     357619   42017   1914737
# Financial services                                   543651   30315   3392275
# Real estate, ownership of dwelling & profession...  1412466  159335  14548185
# Public administration                               1373611  297078   6152124
# Other services                                      1795658  317930   5034623
#
#                                                           5
# Item
# Agriculture, forestry and fishing                   7951890
# Crops                                               4688237
# Livestock                                           2060296
# Forestry and logging                                 550132
# Fishing and aquaculture                              653224
# Mining and quarrying                                  68107
# Manufacturing                                       2189965
# Electricity, gas, water supply & other utility ...   345168
# Construction                                        3449763
# Trade, repair, hotels and restaurants               7448373
# Trade & repair services                             7081391
# Hotels & restaurants                                 366982
# Transport, storage, communication & services re...  3147173
# Railways                                             462413
# Road transport                                      1572288
# Water transport                                        2228
# Air transport                                         13599
# Services incidental to transport                     166600
# Storage                                               10618
# Communication & services related to broadcasting     919427
# Financial services                                  1178022
# Real estate, ownership of dwelling & profession...  3740641
# Public administration                               2078171
# Other services                                      4587589

# %%
# add the rows for each column
c1_states["total"] = c1_states.sum(axis=1)
c2_states["total"] = c2_states.sum(axis=1)
c3_states["total"] = c3_states.sum(axis=1)
c4_states["total"] = c4_states.sum(axis=1)

#calculate %share
c1_states["%share"] = (c1_states["total"]*100)/c1_states["total"].sum(axis=0)
c2_states["%share"] = (c2_states["total"]*100)/c2_states["total"].sum(axis=0)
c3_states["%share"] = (c3_states["total"]*100)/c3_states["total"].sum(axis=0)
c4_states["%share"] = (c4_states["total"]*100)/c4_states["total"].sum(axis=0)


# sort according to % share
c1_states = c1_states.sort_values("%share",ascending=False)
c2_states = c2_states.sort_values("%share",ascending=False)
c3_states = c3_states.sort_values("%share",ascending=False)
c4_states = c4_states.sort_values("%share",ascending=False)

c1_states
# Out:
#                                                           0       1       2  \
# Item
# Real estate, ownership of dwelling & profession...   407099  598448   75330
# Trade, repair, hotels and restaurants                380927  965781   70568
# Agriculture, forestry and fishing                    308507   16233  137447
# Manufacturing                                       1177608  149631  550697
# Trade & repair services                              343492  890921   64624
# Construction                                         165819  133321   82058
# Other services                                       180431  156543  149265
# Crops                                                140421    1659  114976
# Transport, storage, communication & services re...   189656  148302   47347
# Livestock                                             30141   13992   17338
# Road transport                                        46171   54468   35283
# Financial services                                   233618  373045   21079
# Public administration                                346486  183889  119514
# Electricity, gas, water supply & other utility ...   204110   29741  212499
# Communication & services related to broadcasting      44028   46399   12064
# Hotels & restaurants                                  37434   74860    5945
# Fishing and aquaculture                              122201     194     604
# Forestry and logging                                  15744     388    4529
# Mining and quarrying                                   3622     179    1329
# Railways                                              15649    1070       0
# Services incidental to transport                      19272   33211       0
# Air transport                                         46359   12391       0
# Water transport                                       17820       0       0
# Storage                                                 357     763       0
#
#                                                               3        4  \
# Item
# Real estate, ownership of dwelling & profession...  6.97018e+06  7287633
# Trade, repair, hotels and restaurants               4.98632e+06  8557345
# Agriculture, forestry and fishing                   8.01524e+06  5930617
# Manufacturing                                       7.75692e+06  4273567
# Trade & repair services                             4.81778e+06  7763847
# Construction                                        3.70257e+06  7314003
# Other services                                      2.00158e+06  5728645
# Crops                                               4.63673e+06  3070386
# Transport, storage, communication & services re...  2.56062e+06  4020934
# Livestock                                           2.91617e+06  1656104
# Road transport                                      1.45236e+06  2761427
# Financial services                                  1.67149e+06  2010306
# Public administration                               1.03638e+06  2068915
# Electricity, gas, water supply & other utility ...  1.10192e+06   482470
# Communication & services related to broadcasting         479658   884767
# Hotels & restaurants                                     168535   793498
# Fishing and aquaculture                                  110080   704319
# Forestry and logging                                     352254   499808
# Mining and quarrying                                      25186   558824
# Railways                                                 423873   147897
# Services incidental to transport                         190269    71567
# Air transport                                               NaN   125029
# Water transport                                             NaN    26956
# Storage                                                   14459     3290
#
#                                                          total     %share
# Item
# Real estate, ownership of dwelling & profession...  15338693.0  11.601095
# Trade, repair, hotels and restaurants               14960940.0  11.315389
# Agriculture, forestry and fishing                   14408042.0  10.897217
# Manufacturing                                       13908424.0  10.519341
# Trade & repair services                             13880668.0  10.498348
# Construction                                        11397772.0   8.620463
# Other services                                       8216465.0   6.214349
# Crops                                                7964173.0   6.023533
# Transport, storage, communication & services re...   6966862.0   5.269238
# Livestock                                            4633748.0   3.504637
# Road transport                                       4349713.0   3.289813
# Financial services                                   4309534.0   3.259425
# Public administration                                3755181.0   2.840151
# Electricity, gas, water supply & other utility ...   2030739.0   1.535906
# Communication & services related to broadcasting     1466916.0   1.109471
# Hotels & restaurants                                 1080272.0   0.817041
# Fishing and aquaculture                               937398.0   0.708981
# Forestry and logging                                  872723.0   0.660066
# Mining and quarrying                                  589140.0   0.445584
# Railways                                              588489.0   0.445091
# Services incidental to transport                      314319.0   0.237728
# Air transport                                         183779.0   0.138997
# Water transport                                        44776.0   0.033865
# Storage                                                18869.0   0.014271

# %%
#find top sub-sectors contributing to 80% of GDP
from functools import reduce
import itertools

c1_states["%cumShare"] = list(itertools.accumulate(c1_states["%share"],lambda x,y:x+y))
c2_states["%cumShare"] = list(itertools.accumulate(c2_states["%share"],lambda x,y:x+y))
c3_states["%cumShare"] = list(itertools.accumulate(c3_states["%share"],lambda x,y:x+y))
c4_states["%cumShare"] = list(itertools.accumulate(c4_states["%share"],lambda x,y:x+y))


#print top sectors
c1_states.loc[c1_states[c1_states['%cumShare'] <= 80 ].index,'%share']
# Out:
# Item
# Real estate, ownership of dwelling & professional services    11.601095
# Trade, repair, hotels and restaurants                         11.315389
# Agriculture, forestry and fishing                             10.897217
# Manufacturing                                                 10.519341
# Trade & repair services                                       10.498348
# Construction                                                   8.620463
# Other services                                                 6.214349
# Crops                                                          6.023533
# Name: %share, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.barplot(x="%share",y = c1_states.index,data = c1_states)
plt.show()

# %%
c2_states.loc[c2_states[c2_states['%cumShare'] <= 80 ].index,'%share']

plt.figure(figsize=(12,10))
sns.barplot(x="%share",y = c2_states.index,data = c2_states)
plt.show()

# %%
c3_states.loc[c3_states[c3_states['%cumShare'] <= 80 ].index,'%share']
plt.figure(figsize=(12,10))
sns.barplot(x="%share",y = c3_states.index,data = c3_states)
plt.show()

# %%
c4_states.loc[c4_states[c4_states['%cumShare'] <= 80 ].index,'%share']
plt.figure(figsize=(12,10))
sns.barplot(x="%share",y = c4_states.index,data = c4_states)
plt.show()

# %% [markdown]
# ### Part 2 Analyze the drop out ratio for each category of states

# %%
drop_out_data = pd.read_csv("drop_out_ratio.csv")
drop_out_data.set_index("Level of Education - State",inplace=True)
drop_out_data.head()
# Out:
#                            Sl. No.  Primary - 2012-2013  Primary - 2014-2015  \
# Level of Education - State
# A & N Islands                    1                 0.68                 1.21
# Andhra Pradesh                   2                 3.18                 4.35
# Arunachal Pradesh                3                15.16                10.89
# Assam                            4                 6.24                 7.44
# Bihar                            5                  NaN                 2.09
#
#                             Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# Level of Education - State
# A & N Islands                                0.51                       1.23
# Andhra Pradesh                               6.72                       3.36
# Arunachal Pradesh                           10.82                       7.47
# Assam                                       15.36                       7.20
# Bihar                                         NaN                        NaN
#
#                             Upper Primary - 2013-2014  \
# Level of Education - State
# A & N Islands                                    0.51
# Andhra Pradesh                                   3.78
# Arunachal Pradesh                                5.59
# Assam                                            7.05
# Bihar                                            2.98
#
#                             Upper Primary - 2014-2015  Secondary - 2012-2013  \
# Level of Education - State
# A & N Islands                                    1.69                   5.56
# Andhra Pradesh                                   5.20                  12.72
# Arunachal Pradesh                                6.71                  12.93
# Assam                                           10.51                  26.77
# Bihar                                            4.08                  30.14
#
#                             Secondary - 2013-2014  Secondary - 2014-2015  \
# Level of Education - State
# A & N Islands                                7.20                   9.87
# Andhra Pradesh                              12.65                  15.71
# Arunachal Pradesh                           14.49                  17.11
# Assam                                       30.43                  27.06
# Bihar                                       25.33                  25.90
#
#                             Senior Secondary - 2012-2013  \
# Level of Education - State
# A & N Islands                                      14.14
# Andhra Pradesh                                      0.35
# Arunachal Pradesh                                   5.11
# Assam                                               4.69
# Bihar                                                NaN
#
#                             Senior Secondary - 2013-2014  \
# Level of Education - State
# A & N Islands                                      15.87
# Andhra Pradesh                                     11.79
# Arunachal Pradesh                                  17.07
# Assam                                               7.24
# Bihar                                                NaN
#
#                             Senior Secondary - 2014-2015
# Level of Education - State
# A & N Islands                                      16.93
# Andhra Pradesh                                       NaN
# Arunachal Pradesh                                  18.42
# Assam                                                NaN
# Bihar                                                NaN

# %%
drop_out_data = pd.concat([drop_out_data,states_gdp['Per Capita GSDP (Rs.)']],axis=1,join='inner')
drop_out_data.head()
# Out:
#            Sl. No.  Primary - 2012-2013  Primary - 2014-2015  \
# Assam            4                 6.24                 7.44
# Bihar            5                  NaN                 2.09
# Chandigarh       6                  NaN                  NaN
# Goa             11                  NaN                 0.20
# Gujarat         12                 0.74                 0.76
#
#             Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# Assam                       15.36                        7.2
# Bihar                         NaN                        NaN
# Chandigarh                    NaN                        0.1
# Goa                          0.73                        NaN
# Gujarat                      0.89                        5.2
#
#             Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# Assam                            7.05                      10.51
# Bihar                            2.98                       4.08
# Chandigarh                       1.08                       0.44
# Goa                               NaN                       0.07
# Gujarat                          5.55                       6.41
#
#             Secondary - 2012-2013  Secondary - 2013-2014  \
# Assam                       26.77                  30.43
# Bihar                       30.14                  25.33
# Chandigarh                    NaN                    NaN
# Goa                          7.96                   9.58
# Gujarat                     13.55                  21.61
#
#             Secondary - 2014-2015  Senior Secondary - 2012-2013  \
# Assam                       27.06                          4.69
# Bihar                       25.90                           NaN
# Chandigarh                    NaN                         13.65
# Goa                         11.15                         11.26
# Gujarat                     25.04                          0.46
#
#             Senior Secondary - 2013-2014  Senior Secondary - 2014-2015  \
# Assam                               7.24                           NaN
# Bihar                                NaN                           NaN
# Chandigarh                         11.28                         10.55
# Goa                                13.36                         13.91
# Gujarat                             7.83                          7.04
#
#            Per Capita GSDP (Rs.)
# Assam                      60621
# Bihar                      33954
# Chandigarh                250398
# Goa                       271793
# Gujarat                   141263

# %%
#Show correlation between Per Capita GDP and dropout rates
sns.lmplot(y='Per Capita GSDP (Rs.)', x='Primary - 2014-2015', data=drop_out_data )
plt.show()

sns.lmplot(y='Per Capita GSDP (Rs.)', x='Upper Primary - 2014-2015', data=drop_out_data )
plt.show()

sns.lmplot(y='Per Capita GSDP (Rs.)', x='Secondary - 2014-2015', data=drop_out_data )
plt.show()

sns.lmplot(y='Per Capita GSDP (Rs.)', x='Senior Secondary - 2014-2015', data=drop_out_data )
plt.show()
